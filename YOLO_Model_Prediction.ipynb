# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import cv2
import os
import random

# %%
random.choice([1,4,8,5,6])
# Out:
# 8

# %%
model = YOLO(r"C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Cheque_detection_with_YOLOv8\runs\detect\train4\weights\best.pt")

# %%
multi_check_model = YOLO(r"C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Cheque_detection_with_YOLOv8\runs\detect\train4\weights\best.pt")
axis_bank_model = YOLO(r"C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Cheque_detection_with_YOLOv8\runs\detect\train3\weights\best.pt")

# %%
axis_bank_sample = r'C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\50.tif'
sutisign_sample = r'C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\Paramita_Madam_sample.png'
third_party_cheque_1 = r'C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\JPG-2.jpg'
third_party_cheque_2 = r'C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\cheques-407-asterisk.gif'

# %%
def get_random_sample():
    list_of_files = os.listdir(r'C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya')
    random_file = random.choice(list_of_files)
    return r'C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\\' + random_file

# %%
def pred_image(model,pred_img):
    results = model.predict(pred_img,save=True)
    final_image = cv2.cvtColor(results[0].plot(), cv2.COLOR_BGR2RGB)
    plt.imshow(final_image)

# %% [markdown]
# ## AXIS BANK MODEL --Prediction

# %%
pred_image(axis_bank_model, axis_bank_sample)
# Out:
# image 1/1 C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\50.tif: 320x640 1 signature, 94.2ms
# Speed: 5.1ms preprocess, 94.2ms inference, 8.3ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict7

# %%
pred_image(multi_check_model, axis_bank_sample)
# Out:
# image 1/1 C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\50.tif: 320x640 1 signature, 44.8ms
# Speed: 2.0ms preprocess, 44.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict8

# %%
pred_image(multi_check_model, sutisign_sample)
# Out:
# image 1/1 C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\Paramita_Madam_sample.PNG: 288x640 1 signature, 50.8ms
# Speed: 2.0ms preprocess, 50.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict8

# %%
pred_image(axis_bank_model, sutisign_sample)
# Out:
# image 1/1 C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\Paramita_Madam_sample.PNG: 288x640 (no detections), 49.8ms
# Speed: 2.0ms preprocess, 49.8ms inference, 2.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict7

# %%
pred_image(multi_check_model, third_party_cheque_1)
# Out:
# image 1/1 C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\JPG-2.jpg: 320x640 (no detections), 47.8ms
# Speed: 1.0ms preprocess, 47.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict8

# %%
pred_image(multi_check_model, third_party_cheque_2)
# Out:
#     WARNING  stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
#             masks = r.masks  # Masks object for segment masks outputs
#             probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/1) C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\cheques-407-asterisk.gif: 288x640 1 signature, 37.9ms
# Speed: 1.6ms preprocess, 37.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict8

# %%
pred_image(axis_bank_model, get_random_sample())
# Out:
# image 1/1 C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\JPG-2.jpg: 320x640 (no detections), 49.8ms
# Speed: 1.0ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict7

# %%
pred_image(multi_check_model, get_random_sample())
# Out:
# image 1/1 C:\Users\suryavamsib\Desktop\Cheques Signature Verification\Test_Data_Cheques_Collected_by_surya\Paramita_Madam_sample.PNG: 288x640 1 signature, 43.9ms
# Speed: 1.0ms preprocess, 43.9ms inference, 0.0ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict8

# %%
output_image_path = model.predict(axis_bank_sample)

# %%
output_image_path[0].__dir__()

# %%
output_image_path[0].new()

# %%
final_image = cv2.cvtColor(output_image_path[0].plot(), cv2.COLOR_BGR2RGB)

# %%
plt.imshow(final_image)
